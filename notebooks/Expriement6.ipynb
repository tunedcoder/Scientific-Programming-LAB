# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
india_scores = np.array([5,35,24,0,99,1,35,15,27,14])
england_scores = np.array([10,55,34,21,2,7,118,29,32,10])

# %%
plt.plot(np.cumsum(india_scores),label="India")
plt.plot(np.cumsum(england_scores),label="England")
plt.legend()
plt.plot()
# Out:
# []
