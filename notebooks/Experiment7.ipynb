# %% [markdown]
# # IMAGE PROCESSING

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import matplotlib.image as mpimg
from PIL import Image
import matplotlib.pyplot as plt

# %%
i = Image.open("../index.jpeg")

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=124x124>

# %%
np.asarray(Image.open('../index.jpeg').convert('L'))
# Out:
# array([[156, 157, 157, ..., 153, 153, 153],
#        [156, 157, 157, ..., 154, 154, 154],
#        [156, 157, 157, ..., 149, 149, 149],
#        ...,
#        [118, 106, 119, ..., 105, 109, 106],
#        [122, 115, 130, ..., 116, 124, 124],
#        [135, 132, 149, ..., 121, 130, 130]], dtype=uint8)

# %%
plt.hist(i.histogram())
# Out:
# (array([444.,  90.,  99.,  54.,  48.,   9.,   9.,   9.,   3.,   3.]),
#  array([  0. ,  39.9,  79.8, 119.7, 159.6, 199.5, 239.4, 279.3, 319.2,
#         359.1, 399. ]),
#  <BarContainer object of 10 artists>)

# %%
from PIL import ImageFilter

# %%
im1 = i.filter(ImageFilter.SMOOTH)
im2 = i.filter(ImageFilter.SMOOTH_MORE)
im3 = i.filter(ImageFilter.BLUR) 
im4 = i.filter(ImageFilter.GaussianBlur(7))

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=124x124>

# %%
im2
# Out:
# <PIL.Image.Image image mode=RGB size=124x124>

# %%
im3
# Out:
# <PIL.Image.Image image mode=RGB size=124x124>

# %%
im4
# Out:
# <PIL.Image.Image image mode=RGB size=124x124>

# %%
i.histogram()[-20:]
# Out:
# [3, 1, 1, 1, 1, 1, 1, 3, 2, 2, 2, 1, 0, 2, 0, 1, 0, 0, 0, 4]
